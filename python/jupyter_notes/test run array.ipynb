# %%
arr = [1,2,3,4,5]
target = 9

def linearsearch(arr, target):
    for i in arr:
        if i == target:
            return i       
    return -1
        
linearsearch(arr, target)
# Out:
# -1

# %%
def issorted(arr):
    for i in range(len(arr) - 1, 0, -1):
        
        if arr[i] > arr[i - 1]:
            return False
        
    return True
    
            
        
# arr = [1,2,3,4,5]    
arr = [5,4,3,3,2,1]
issorted(arr)
# Out:
# True

# %%
def countmax(arr):
    maxval = max(arr)
    return arr.count(maxval)

countmax(arr = [1,2,3,4,5,5])
# Out:
# 2

# %%
from icecream import ic

def rm_dup(arr):
    if not arr:
        return 0
    
    slow = 0

    for fast in range(1, len(arr)):
        if arr[fast] != arr[slow]:
            slow = slow + 1 #slow += 1
            arr[slow] = arr[fast]

    return slow + 1

arr = [1,2,3,3,4,5,5]
rm_dup(arr)
ic(arr)
# Out:
# ic| arr: [1, 2, 3, 4, 5, 5, 5]
# [1, 2, 3, 4, 5, 5, 5]

# %%
def remove_duplicates(arr):
    """Remove duplicates in-place, return new length"""
    if not arr:
        return 0
    
    slow = 0  # Position for next unique element
    
    for fast in range(1, len(arr)):
        if arr[fast] != arr[slow]:
            slow += 1
            arr[slow] = arr[fast]
    
    return slow + 1

n = remove_duplicates(arr)
print(arr[:n])  # [1, 2, 3, 4, 5] ✓
# Out:
# [1, 2, 3, 4, 5]
