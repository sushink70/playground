# %% [markdown]
# Code
# Testcase
# Test Result
# Test Result
# 16. 3Sum Closest
# Medium
# Topics
# premium lock icon
# Companies
# Given an integer array nums of length n and an integer target, find three integers in nums such that the sum is closest to target.
#
# Return the sum of the three integers.
#
# You may assume that each input would have exactly one solution.
#
#
#
# Example 1:
#
# Input: nums = [-1,2,1,-4], target = 1
# Output: 2
# Explanation: The sum that is closest to the target is 2. (-1 + 2 + 1 = 2).
# Example 2:
#
# Input: nums = [0,0,0], target = 1
# Output: 0
# Explanation: The sum that is closest to the target is 0. (0 + 0 + 0 = 0).
#
#
# Constraints:
#
# 3 <= nums.length <= 500
# -1000 <= nums[i] <= 1000
# -104 <= target <= 104
#
# Here are **7 test examples** for the "3Sum Closest" problem, covering various edge cases like exact matches, negative numbers, ties, and small arrays.
#
# ### Example 1: Exact Match
# **Input:** `nums = [1, 1, 1, 0]`, `target = 3`
# **Output:** `3`
# **Explanation:** The sum `1 + 1 + 1 = 3` is exactly equal to the target.
#
# ### Example 2: Small Array (Length 3)
# **Input:** `nums = [1, 2, 3]`, `target = 100`
# **Output:** `6`
# **Explanation:** Since there are only three numbers, we must select all of them. `1 + 2 + 3 = 6`.
#
# ### Example 3: Mixed Positive and Negative Numbers
# **Input:** `nums = [4, -2, -3, 3, 2]`, `target = 1`
# **Output:** `2`
# **Explanation:** The closest sum to 1 is `2`. (Calculation: `-3 + 2 + 3 = 2`, which has a distance of 1 from the target).
#
# ### Example 4: Large Negative Target
# **Input:** `nums = [-10, -10, -10, 5, 2]`, `target = -35`
# **Output:** `-30`
# **Explanation:** The smallest possible sum is `-10 + -10 + -10 = -30`. Even though it is 5 units away, it is the closest achievable sum.
#
# ### Example 5: Larger Numbers / Gap
# **Input:** `nums = [10, 20, 30, 40]`, `target = 82`
# **Output:** `80`
# **Explanation:**
# * `10 + 30 + 40 = 80` (Distance: 2)
# * `20 + 30 + 40 = 90` (Distance: 8)
# * The sum `80` is closer to `82`.
#
# ### Example 6: Tie for Distance (Lower and Higher)
# **Input:** `nums = [1, 2, 3, 7]`, `target = 8`
# **Output:** `6` **OR** `10`
# **Explanation:** Both sums are equally close (distance of 2):
# * `1 + 2 + 3 = 6` (8 - 6 = 2)
# * `1 + 2 + 7 = 10` (10 - 8 = 2)
# *(Note: Most standard problem definitions accept either answer in a tie scenario).*
#
# ### Example 7: Handling Duplicates
# **Input:** `nums = [1, 1, 1, 10, 10, 10]`, `target = 25`
# **Output:** `21`
# **Explanation:**
# * `10 + 10 + 10 = 30` (Distance: 5)
# * `10 + 10 + 1 = 21` (Distance: 4)
# * The sum `21` is closest.
#
# ---
#
# **Would you like me to provide the Python or C++ solution code to run against these test cases?**

# %%
from typing import List


class Solution:
    def threeSumClosest(self, nums: List[int], target: int) -> int:
        
        nums.sort()



        # sum = nums[i] + nums[j] + nums[k] -> close to target
        # compare -> sum - target => distance, take smallest number by variable the closest-varirable
        # return closest.

        #i - for loop for iteration
        for i in range(len(nums) - 2):
            # print(nums[i])
            while left < right:
                sum = nums[i] + nums[left] + nums[right]
                distance = sum - target


                
                



nums = [-1,2,1,-4]
target = 1
# nums = [0,0,0]
# target = 1
solution = Solution()
result = solution.threeSumClosest(nums=nums, target=target)
print(result)
# Out:
# None

# %%
closest_sum = float('inf')
print(closest_sum)
# Out:
# inf

# %%
from typing import List

class Solution:
    def threeSumClosest(self, nums: List[int], target: int) -> int:
        nums.sort()  # O(n log n)
        
        closest_sum = float('inf')
        min_distance = float('inf')
        
        # Fix the first element
        for i in range(len(nums) - 2):  # -2 because we need at least 3 elements
            left = i + 1
            right = len(nums) - 1
            
            # Two-pointer scan
            while left < right:
                current_sum = nums[i] + nums[left] + nums[right]
                distance = abs(current_sum - target)
                
                # Update closest if this is better
                if distance < min_distance:
                    min_distance = distance
                    closest_sum = current_sum
                
                # Early exit: can't get better than exact match
                if current_sum == target:
                    return target
                
                # Move pointers based on comparison
                if current_sum < target:
                    left += 1   # Need larger sum
                else:
                    right -= 1  # Need smaller sum
        
        return closest_sum
    
nums = [-1,2,1,-4]
target = 1
# nums = [0,0,0]
# target = 1
solution = Solution()
result = solution.threeSumClosest(nums=nums, target=target)
print(result)
# Out:
# 2
