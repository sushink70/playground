# %%
class TrieNode:
    def __init__(self) -> None:
        self.children = {}
        self.is_end = False

class Solution:
    
    def __init__(self) -> None:
        self.root = TrieNode()

    def create_trienode(self, words):

        node = self.root

        for word in words:
            for char in word:
                if char not in node.children:
                    node.children[char] = TrieNode()
                node = node.children[char]
            if not node.is_end:
                node.is_end = True

        return node
        
        

    def longestCommonPrefix(self, words):
        return_value = self.create_trienode(words)
        print(return_value.children)
        
        
words = ["flower","flow","flight"]
s = Solution()
result = s.longestCommonPrefix(words)
# print(result)  # Expected output: "fl"

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False

class Trie:
    def __init__(self):
        self.root = TrieNode()

    def insert(self, word):
        node = self.root
        for char in word:
            if char not in node.children:
                node.children[char] = TrieNode()
            node = node.children[char]
        node.is_end = True

words = ["flower","flow","flight"]
trie = Trie()
for word in words:
    trie.insert(word)
print(trie.root.children['f'].children['l'])  # Debug: Print the children of the root node

# %% [markdown]
# 14. Longest Common Prefix
# Easy
# Topics
# premium lock iconCompanies
#
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string "".
#
#
#
# Example 1:
#
# Input: strs = ["flower","flow","flight"]
# Output: "fl"
#
# Example 2:
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.
#
#
#
# Constraints:
#
#     1 <= strs.length <= 200
#     0 <= strs[i].length <= 200
#     strs[i] consists of only lowercase English letters if it is non-empty.

# %%
def longestCommonPrefix(strs):
    if not strs:
        return ""

    prefix = strs[0]

    for s in strs[1:]:
        while not s.startswith(prefix):
            prefix = prefix[:-1]
            if prefix == "":
                return ""
    return prefix

words = ["flower","flow","floght"]
result = longestCommonPrefix(words)
print(result)  # Expected output: "fl"

# %%
class Node:
    def __init__(self):
        self.children = {}
        self.is_end = False
        self.count = 0

class TrieNode:
    def longestCommonPrefix(self, strs):
        root = Node()
        print("Root children:", root)
        n = len(strs)
        print("Number of strings:", n)
        for s in strs:
            curr = root
            for ch in s:
                if ch not in curr.children:
                    curr.children[ch] = Node()                    
                curr = curr.children[ch]

                curr.count = curr.count + 1
                # print(f"Character: {ch}, Count: {curr.count}")
            curr.is_end = True
            

        
        curr = root
        
        prefix = []

        while (len(curr.children) == 1 and curr.is_end == False):
            ch, next_node = next(iter(curr.children.items()))
            # print("Current character:", ch)
            print("Next node count:", next_node)
            if next_node.count != n:
                break
            prefix.append(ch)
            curr = next_node

        return "".join(prefix)

words = ["flight", "flow", "floerw"]
s = TrieNode()
result = s.longestCommonPrefix(words)
# print(result)
# Out:
# Root children: <__main__.Node object at 0x7ff6b7720d70>
# Number of strings: 3
# Next node count: <__main__.Node object at 0x7ff6d415afd0>
# Next node count: <__main__.Node object at 0x7ff6b77e5590>
